# %%
import pandas as pd

# %%
cleantournamentteamdata_df = pd.read_csv("CSV/Tournament Team Data.csv")

# %%
cleantournamentteamdata_df.head()
# Out:
#    YEAR  SEED     TEAM  ROUND  KENPOM ADJUSTED EFFICIENCY  \
# 0  2022     1   Kansas      1                        25.5
# 1  2022     1  Arizona     16                        27.2
# 2  2022     1  Gonzaga     16                        33.0
# 3  2022     1   Baylor     32                        26.3
# 4  2022     2     Duke      4                        23.7
#
#    KENPOM ADJUSTED OFFENSE  KENPOM ADJUSTED DEFENSE  KENPOM ADJUSTED TEMPO  \
# 0                    119.4                     93.9                   69.1
# 1                    119.6                     92.4                   72.2
# 2                    121.8                     88.8                   72.5
# 3                    117.9                     91.6                   67.2
# 4                    119.4                     95.7                   67.4
#
#    BARTTORVIK ADJUSTED EFFICIENCY  BARTTORVIK ADJUSTED OFFENSE  ...  \
# 0                            27.2                        120.1  ...
# ...

# %%
cleantournamentteamdata_df = cleantournamentteamdata_df.drop("TEAM.1", axis = 1)

# %%
cleantournamentteamdata_df.head()
# Out:
#    YEAR  SEED     TEAM  ROUND  KENPOM ADJUSTED EFFICIENCY  \
# 0  2022     1   Kansas      1                        25.5
# 1  2022     1  Arizona     16                        27.2
# 2  2022     1  Gonzaga     16                        33.0
# 3  2022     1   Baylor     32                        26.3
# 4  2022     2     Duke      4                        23.7
#
#    KENPOM ADJUSTED OFFENSE  KENPOM ADJUSTED DEFENSE  KENPOM ADJUSTED TEMPO  \
# 0                    119.4                     93.9                   69.1
# 1                    119.6                     92.4                   72.2
# 2                    121.8                     88.8                   72.5
# 3                    117.9                     91.6                   67.2
# 4                    119.4                     95.7                   67.4
#
#    BARTTORVIK ADJUSTED EFFICIENCY  BARTTORVIK ADJUSTED OFFENSE  ...  \
# 0                            27.2                        120.1  ...
# ...

# %%
cleantournamentteamdata_df.dtypes
# Out:
# YEAR                                int64
# SEED                                int64
# TEAM                               object
# ROUND                               int64
# KENPOM ADJUSTED EFFICIENCY        float64
# KENPOM ADJUSTED OFFENSE           float64
# KENPOM ADJUSTED DEFENSE           float64
# KENPOM ADJUSTED TEMPO             float64
# BARTTORVIK ADJUSTED EFFICIENCY    float64
# BARTTORVIK ADJUSTED OFFENSE       float64
# BARTTORVIK ADJUSTED DEFENSE       float64
# BARTHAG                           float64
# ELITE SOS                         float64
# BARTTORVIK ADJUSTED TEMPO         float64
# 2PT %                             float64
# 3PT %                             float64
# FREE THROW %                      float64
# EFG %                             float64
# FREE THROW RATE                   float64
# 3PT RATE                          float64
# ASSIST %                          float64
# OFFENSIVE REBOUND %               float64
# ...

# %%
cleantournamentteamdata_df = cleantournamentteamdata_df.dropna(axis='columns', how='all')
cleantournamentteamdata_df.head()
# Out:
#    YEAR  SEED     TEAM  ROUND  KENPOM ADJUSTED EFFICIENCY  \
# 0  2022     1   Kansas      1                        25.5
# 1  2022     1  Arizona     16                        27.2
# 2  2022     1  Gonzaga     16                        33.0
# 3  2022     1   Baylor     32                        26.3
# 4  2022     2     Duke      4                        23.7
#
#    KENPOM ADJUSTED OFFENSE  KENPOM ADJUSTED DEFENSE  KENPOM ADJUSTED TEMPO  \
# 0                    119.4                     93.9                   69.1
# 1                    119.6                     92.4                   72.2
# 2                    121.8                     88.8                   72.5
# 3                    117.9                     91.6                   67.2
# 4                    119.4                     95.7                   67.4
#
#    BARTTORVIK ADJUSTED EFFICIENCY  BARTTORVIK ADJUSTED OFFENSE  ...  \
# 0                            27.2                        120.1  ...
# ...

# %%
cleantournamentteamdata_df["Win"] = ['1' if i == 1 else '0' for i in cleantournamentteamdata_df["ROUND"]]
cleantournamentteamdata_df.head()
# Out:
#    YEAR  SEED     TEAM  ROUND  KENPOM ADJUSTED EFFICIENCY  \
# 0  2022     1   Kansas      1                        25.5
# 1  2022     1  Arizona     16                        27.2
# 2  2022     1  Gonzaga     16                        33.0
# 3  2022     1   Baylor     32                        26.3
# 4  2022     2     Duke      4                        23.7
#
#    KENPOM ADJUSTED OFFENSE  KENPOM ADJUSTED DEFENSE  KENPOM ADJUSTED TEMPO  \
# 0                    119.4                     93.9                   69.1
# 1                    119.6                     92.4                   72.2
# 2                    121.8                     88.8                   72.5
# 3                    117.9                     91.6                   67.2
# 4                    119.4                     95.7                   67.4
#
#    BARTTORVIK ADJUSTED EFFICIENCY  BARTTORVIK ADJUSTED OFFENSE  ...  \
# 0                            27.2                        120.1  ...
# ...

# %%
cleantournamentteamdata_df.to_csv("CleanTournamentTeamData.csv", index=False)
