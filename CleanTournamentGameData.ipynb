# %%
import pandas as pd

# %%
cleantournementgamedata_df = pd.read_csv("CSV/Tournament Game Data.csv")

# %%
cleantournementgamedata_df.head()
# Out:
#    YEAR  SEED         TEAM  TEAM ROUND  CURRENT ROUND  \
# 0  2022     1      Gonzaga          16             64
# 1  2022    16  Georgia St.          64             64
# 2  2022     8    Boise St.          64             64
# 3  2022     9      Memphis          32             64
# 4  2022     5  Connecticut          64             64
#
#    KENPOM ADJUSTED EFFICIENCY  KENPOM ADJUSTED OFFENSE  \
# 0                        33.0                    121.8
# 1                         1.8                    101.5
# 2                        16.4                    108.4
# 3                        16.2                    110.4
# 4                        19.3                    113.9
#
#    KENPOM ADJUSTED DEFENSE  KENPOM ADJUSTED TEMPO  \
# 0                     88.8                   72.5
# 1                     99.7                   67.1
# 2                     92.0                   64.6
# 3                     94.1                   70.3
# 4                     94.6                   64.9
#
#    BARTTORVIK ADJUSTED EFFICIENCY  ...  OP D REB %  BLOCKED %  \
# 0                            31.8  ...        71.0        6.6
# 1                             1.4  ...        67.2        8.9
# 2                            15.2  ...        69.4        8.9
# 3                            17.5  ...        62.5        9.1
# 4                            18.6  ...        62.0        8.3
#
#    TURNOVER % DEFENSE  WINS ABOVE BUBBLE  WIN %  \
# 0                17.0                6.7  89.66
# 1                22.7               -5.2  60.00
# 2                20.1                3.5  78.79
# 3                20.9                1.4  67.74
# 4                18.0                3.2  71.88
#
#    POINTS PER POSSESSION OFFENSE  POINTS PER POSSESSION DEFENSE  SCORE  ID  \
# 0                          1.190                          0.885     93   1
# 1                          0.993                          0.978     72   2
# 2                          1.038                          0.928     53   3
# 3                          1.056                          0.957     64   4
# 4                          1.099                          0.953     63   5
#
#         TEAM.1
# 0      Gonzaga
# 1  Georgia St.
# 2    Boise St.
# 3      Memphis
# 4  Connecticut
#
# [5 rows x 44 columns]

# %%
cleantournementgamedata_df = cleantournementgamedata_df.drop("TEAM.1", axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/6b/p58wttvj1r7fltb9yl4bgbk00000gn/T/ipykernel_30019/2782419597.py in <module>
# ----> 1 cleantournementgamedata_df = cleantournementgamedata_df.drop("TEAM.1", axis = 1)
#       2 cleantournementgamedata_df.head()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['TEAM.1'] not found in axis"

# %%
cleantournementgamedata_df.head()
# Out:
#    YEAR  SEED         TEAM  TEAM ROUND  CURRENT ROUND  \
# 0  2022     1      Gonzaga          16             64
# 1  2022    16  Georgia St.          64             64
# 2  2022     8    Boise St.          64             64
# 3  2022     9      Memphis          32             64
# 4  2022     5  Connecticut          64             64
#
#    KENPOM ADJUSTED EFFICIENCY  KENPOM ADJUSTED OFFENSE  \
# 0                        33.0                    121.8
# 1                         1.8                    101.5
# 2                        16.4                    108.4
# 3                        16.2                    110.4
# 4                        19.3                    113.9
#
#    KENPOM ADJUSTED DEFENSE  KENPOM ADJUSTED TEMPO  \
# 0                     88.8                   72.5
# 1                     99.7                   67.1
# 2                     92.0                   64.6
# 3                     94.1                   70.3
# 4                     94.6                   64.9
#
#    BARTTORVIK ADJUSTED EFFICIENCY  ...  OP O REB %  OP D REB %  BLOCKED %  \
# 0                            31.8  ...        23.0        71.0        6.6
# 1                             1.4  ...        30.7        67.2        8.9
# 2                            15.2  ...        21.9        69.4        8.9
# 3                            17.5  ...        31.0        62.5        9.1
# 4                            18.6  ...        27.5        62.0        8.3
#
#    TURNOVER % DEFENSE  WINS ABOVE BUBBLE  WIN %  \
# 0                17.0                6.7  89.66
# 1                22.7               -5.2  60.00
# 2                20.1                3.5  78.79
# 3                20.9                1.4  67.74
# 4                18.0                3.2  71.88
#
#    POINTS PER POSSESSION OFFENSE  POINTS PER POSSESSION DEFENSE  SCORE  ID
# 0                          1.190                          0.885     93   1
# 1                          0.993                          0.978     72   2
# 2                          1.038                          0.928     53   3
# 3                          1.056                          0.957     64   4
# 4                          1.099                          0.953     63   5
#
# [5 rows x 43 columns]

# %%
cleantournementgamedata_df.
